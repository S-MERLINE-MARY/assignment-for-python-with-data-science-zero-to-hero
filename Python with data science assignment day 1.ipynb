# %%
# For plotting the data
import matplotlib.pyplot as plt
import seaborn as sns
# For data manipultaion
import pandas as pd
# For scientific or mathematical computations
import numpy as np

# %%
x1 = 3 * np.random.rand(10, 2)
y1 = 4 + 3 *x1* np.random.randn(10, 2)

# %%
print(x1.shape)
print(y1.shape)
# Out:
# (10, 2)
# (10, 2)

# %%
plt.scatter(x1, y1)
plt.title("Scatter plot between $X$ and $Y$")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.show()

# %%
print(x1.flatten())
# Out:
# [1.99457862 2.25919102 0.39281409 1.32806301 0.7634941  0.61912777
#  0.34578107 1.55393014 1.78637279 0.49543353 1.88909088 2.77140867
#  1.55433554 1.3085443  2.27329106 2.85129271 0.12987976 1.74658957
#  1.10448632 0.5708458 ]

# %%
print(y1.flatten())
# Out:
# [ 8.20204906 -3.70090421  3.3055896   2.98957432  1.91036774  3.31814221
#   5.87859419  1.99327551  0.8696561   6.57568971  7.95554511 12.66559688
#   0.21131732 11.54178143  4.39296393  5.89440958  3.77670207  0.78319482
#   5.58453996  4.31327029]

# %%
plt.scatter(x1, y1, c="red")
plt.title("Red colored scatter plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.show()

# %%
import plotly.express as px

# %%
# Importing the iris dataset
df = px.data.iris()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="65c5dc15-f3e4-4e29-b6db-63b61ea23aff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65c5dc15-f3e4-4e29-b6db-63b61ea23aff")) {
#                     Plotly.newPlot(
#                         '65c5dc15-f3e4-4e29-b6db-63b61ea23aff',
# ...

# %%
#changing size
plt.scatter(x1, y1, s=100)
plt.title("Increased size scatter plots")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
plt.show()

# %%
#Labeling data points
x1 = 3 * np.random.rand(10, 1)
y1 = 4 + 3 *x1* np.random.randn(10, 1)
 
x2 = 2 * np.random.rand(10, 1)
y2 = 2 + 4 *x1* np.random.randn(10, 1)
 
 
dataset = [(x1, y1), 
           (x2, y2)]
 
 
plt.scatter(dataset[0][0], dataset[0][1], c="red", s=20, label="From X1, Y1")
plt.scatter(dataset[1][0], dataset[1][1], c="green", s=100, label="From X2, Y2")
plt.title("Labelled data")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
# For enabling the labeling
plt.legend()
plt.show()

# %%
#Changing the shapes of "dots" (Using markers)¶
plt.scatter(dataset[0][0], dataset[0][1], c="red", s=20, label="From X1, Y1", marker="*")
plt.scatter(dataset[1][0], dataset[1][1], c="green", s=100, label="From X2, Y2", marker="^")
plt.title("Labelled data")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
plt.legend()
plt.show()

# %%
#Changing the edge colors
 
plt.scatter(dataset[0][0], dataset[0][1], c="red", s=100, label="From X1, Y1", marker="o", edgecolors="k")
plt.scatter(dataset[1][0], dataset[1][1], c="green", s=100, label="From X2, Y2", marker="^", edgecolors="y")
plt.title("Labelled data")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
plt.legend()
plt.show()

# %%
#Shorthand syntax for scatter plots¶
 
plt.plot(dataset[0][0], dataset[0][1], "ro", label="From X1, Y1")
plt.plot(dataset[1][0], dataset[1][1], "g^", label="From X2, Y2")
plt.title("Labelled data")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
plt.legend()
plt.show()

# %%
#Line plot
 
y1 = np.array([50, 100, 150, 200, 250])
plt.plot(y1)
plt.title("Line plot")
plt.xlabel("$X$ axis")
plt.xticks([0, 1, 2, 3, 4])
plt.yticks([50, 100, 150, 200, 250])
plt.ylabel("$Y$ axis")
plt.show()

# %%
x1 = np.array([0, 1, 2, 3, 4])
y1 = np.array([50, 100, 150, 200, 250])
plt.plot(x1, y1)
plt.title("Line plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.show()

# %%
#Changing the color of the line
 
x1 = np.array([0, 1, 2, 3, 4])
y1 = np.array([50, 100, 150, 200, 250])
plt.plot(x1, y1, c="r")
plt.title("Line plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.show()

# %%
#Changing the width of line¶
 
x1 = np.array([0, 1, 2, 3, 4])
y1 = np.array([50, 100, 150, 200, 250])
plt.plot(x1, y1, linewidth=20)
plt.title("Line plot")
plt.xlabel("$X$-axis")
plt.ylabel("$Y$-axis")
plt.show()

# %%
#Plotting two lines on same graph¶
x = np.array([i*2 for i in range(1, 11)])
 
y1 = np.array([i*2 for i in range(1, 11)])
 
y2 = np.array([3, 6, 9, 12, 15, 18, 21, 24, 27, 30])
 
 
dataset = [(x, y1), 
           (x, y2)]
 
 
plt.plot(dataset[0][0], dataset[0][1], c="red",label="From X1, Y1")
plt.plot(dataset[1][0], dataset[1][1], c="green", label="From X2, Y2")
plt.title("Labelled lines")
plt.xlabel("$X-axis$")
plt.ylabel("$Y-axis$")
plt.legend()
plt.show()

# %%
x = np.array([i*2 for i in range(1, 11)])
y1 = np.array([i*2 for i in range(1, 11)])
 
y2 = np.array([3, 6, 9, 12, 15, 18, 21, 24, 27, 30])
 
 
dataset = [(x, y1), 
           (x, y2)]
 
 
plt.plot(dataset[0][0], dataset[0][1], c="red",label="From X1, Y1", linestyle="dotted")
plt.plot(dataset[1][0], dataset[1][1], c="green", label="From X2, Y2", linestyle="dashed")
plt.title("Labelled lines")
plt.xlabel("$X-axis$")
plt.ylabel("$Y-axis$")
plt.legend()
plt.show()

# %%
x = np.array([i*2 for i in range(1, 11)])
y1 = np.array([i*2 for i in range(1, 11)])
 
y2 = np.array([3, 6, 9, 12, 15, 18, 21, 24, 27, 30])
 
 
dataset = [(x, y1), 
           (x, y2)]
 
 
plt.scatter(dataset[0][0], dataset[0][1], c="red",label="From X1, Y1")
plt.plot(dataset[1][0], dataset[1][1], c="green", label="From X2, Y2")
plt.title("Labelled lines")
plt.xlabel("$X-axis$")
plt.ylabel("$Y-axis$")
plt.legend()
plt.show()

# %%
#Subplots
 
x = np.array([i*2 for i in range(1, 11)])
y1 = np.array([i*2 for i in range(1, 11)])
 
y2 = np.array([3, 6, 9, 12, 15, 18, 21, 24, 27, 30])
 
 
dataset = [(x, y1), 
           (x, y2)]
 
plt.subplot(1, 2, 1)
plt.plot(dataset[0][0], dataset[0][1], c="red",label="Red Line")
plt.title("Red line")
plt.xlabel("$X-axis$")
plt.ylabel("$Y-axis$")
plt.legend()
 
 
plt.subplot(1, 2, 2)
plt.plot(dataset[1][0], dataset[1][1], c="green", label="Green Line")
plt.title("Green line")
plt.xlabel("$X-axis$")
plt.ylabel("$Y-axis$")
plt.legend()
 
plt.subplots_adjust(left=2, right=4)
plt.show()

# %%
#Bar Charts (Vertical)¶
x = np.array(["A", "B", "C", "D", "E"])
y = np.array([np.random.randint(1, 50) for _ in range(5)])
 
plt.bar(x, y)
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.title("Bar chart")
plt.show()

# %%
plt.subplot(1, 2, 1)
plt.bar(x, y, color="red")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.title("Bar charts (Red)")
 
 
plt.subplot(1, 2, 2)
plt.bar(x, y, color="green", width=0.2)
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.title("Bar charts (Green)")
 
 
 
plt.subplots_adjust(left=2, right=4)
plt.show()

# %%
#Horizontal Bar Graph
 
plt.barh(x, y)
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.title("Horizonal Bar chart")
plt.show()

# %%
#Stacked bar graph (vertical)
 
X = ["USA", "China", "Russia"]
 
gold = np.array([20, 10, 7])
bronze = np.array([31, 21, 20])
silver = np.array([41, 28, 19])
 
plt.bar(X, gold,  color="y", label="gold")
plt.bar(X, bronze, bottom=gold, color="r", label="bronze")
plt.bar(X, silver, bottom=gold + bronze, color="g", label="silver")
plt.legend()
plt.show()

# %%
X = ["USA", "China", "Russia"]
 
gold = np.array([20, 10, 7])
bronze = np.array([31, 21, 20])
silver = np.array([41, 28, 19])
 
plt.barh(X, gold,  color="y", label="gold")
plt.barh(X, bronze, left=gold, color="r", label="bronze")
plt.barh(X, silver, left=gold + bronze, color="g", label="silver")
plt.legend()
plt.show()

# %%
#piechart
omlete_ingredient = ["Egg", "Oil", "Spices", "Stove"]
percetage_ing = np.array([35, 20, 15, 30])
 
# The figsize attribute allows us to specify the width and height of a figure in unit inches.
 
plt.figure(figsize=(16, 8))
 
plt.pie(percetage_ing, labels=omlete_ingredient)
plt.title("Omlete Ingredients")
plt.show()

# %%
exploding_values = [0.2, 0, 0, 0]
 
omlete_ingredient = ["Egg", "Oil", "Spices", "Stove"]
percetage_ing = np.array([35, 20, 30, 15])
 
# The figsize attribute allows us to specify the width and height of a figure in unit inches.
 
plt.figure(figsize=(16, 8))
 
plt.pie(percetage_ing, labels=omlete_ingredient, explode=exploding_values)
plt.title("Omlete Ingredients")
plt.show()

# %%
omlete_ingredient = ["Egg", "Oil", "Spices", "Stove"]
percetage_ing = np.array([35, 20, 30, 15])
colors = ["gray", "yellow", "red", "black"]
 
 
# The figsize attribute allows us to specify the width and height of a figure in unit inches.
 
plt.figure(figsize=(16, 8))
 
plt.pie(percetage_ing, labels=omlete_ingredient, colors=colors)
plt.title("Omlete Ingredients")
plt.legend()
plt.show()

# %%
omlete_ingredient = ["Egg", "Oil", "Spices", "Stove", "Pepper"]
percetage_ing = np.array([35, 20, 30, 10, 5])
colors = ["gray", "yellow", "red", "green", "gold"]
 
 
# The figsize attribute allows us to specify the width and height of a figure in unit inches.
 
plt.figure(figsize=(16, 8))
 
plt.pie(percetage_ing, labels=omlete_ingredient, colors=colors, autopct="%1.1f%%")
plt.title("Omlete Ingredients")
plt.legend()
plt.show()

# %%
heights = np.random.normal(170, 10, 250)
 
plt.hist(heights, edgecolor="red")
plt.title("Histogram of heights")
plt.xlabel("Height in cm")
plt.ylabel("Number of People")
plt.show()

# %%
height = [189, 185, 195, 149, 189, 147, 154, 
          174, 169, 195, 159, 192, 155, 191, 
          153, 157, 140, 144, 172, 157, 181, 
          182, 166, 167]
 
print((max(height) - min(height))/15)
# Out:
# 3.6666666666666665

# %%
height = [189, 185, 195, 149, 189, 147, 154, 
          174, 169, 195, 159, 192, 155, 191, 
          153, 157, 140, 144, 172, 157, 181, 
          182, 166, 167]
  
plt.hist(height, edgecolor="red", bins=15)
plt.title("Histogram of height")
plt.xlabel("Height in cm")
plt.ylabel("Frequency")
plt.show()

# %%
 import pandas as pd
import plotly.express as px

# %%
 
df = pd.read_csv('iris.data')
df.columns = ['x1', 'x2', 'x3', 'x4', 'class']
df

# %%
fig = px.violin(df, y="x2", x="class", color="class", box=True, points="all", hover_data=df.columns)
fig.show()
